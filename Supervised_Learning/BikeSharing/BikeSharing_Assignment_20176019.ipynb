# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
import sqlite3
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import metrics
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer
from sklearn.neighbors import KNeighborsClassifier
import gensim
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle
# nltk.download('stopwords')
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.preprocessing import LabelBinarizer

# %%
datafr1=pd.read_csv('hour.csv')
datafr1.head()
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1   0        0        6           0
# 1        2  1/1/2011       1   0     1   1        0        6           0
# 2        3  1/1/2011       1   0     1   2        0        6           0
# 3        4  1/1/2011       1   0     1   3        0        6           0
# 4        5  1/1/2011       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
datafr1.shape
# Out:
# (17379, 17)

# %%
datafr2=pd.read_csv('hour.csv')
datafr2.head()
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1   0        0        6           0
# 1        2  1/1/2011       1   0     1   1        0        6           0
# 2        3  1/1/2011       1   0     1   2        0        6           0
# 3        4  1/1/2011       1   0     1   3        0        6           0
# 4        5  1/1/2011       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
datafr2.shape
# Out:
# (17379, 17)

# %%
datafr1.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %%
datafr2.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# ### The target variable we got is cnt which is a continous variable

# %% [markdown]
# Checking for null values

# %%
datafr1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
#  ###### Now , plot the count plots for various discrete variables .  the various discrete variables are season, holiday, weather etc

# %%
sns.set(style="darkgrid")
ax=sns.countplot(x="season",data=datafr1)
ax

# %%
sns.set(style="darkgrid")
ax=sns.countplot(x="holiday",data=datafr1)
ax

# %%
sns.set(style="darkgrid")
ax=sns.countplot(x="workingday",data=datafr1)
ax

# %%
sns.set(style="darkgrid")
ax=sns.countplot(x="weathersit",data=datafr1)
ax

# %% [markdown]
# ##### Now, lets check histogram plots for our continous features

# %%
datafr1.hist('temp')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027A08BBB048>]],
#       dtype=object)

# %%
datafr1.hist('atemp',color='green')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027A0A3A9E10>]],
#       dtype=object)

# %%
datafr1.hist('hum',color='purple')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027A0A46D7B8>]],
#       dtype=object)

# %%
datafr1.hist('windspeed',color='orange')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027A0A454048>]],
#       dtype=object)

# %%
corrMat = datafr1.corr()
mask = np.array(corrMat)
mask[np.tril_indices_from(mask)] = False
fig, ax= plt.subplots(figsize=(20,10))
sns.heatmap(corrMat, mask=mask,vmax=1., square=True,annot=True)

# %% [markdown]
# #####  from the above correlation plot , temp/atemp are highly correlated. hence, one of them can be removed
# #### cnt is highly correlated with registered (so that's an important feature to predict demand)

# %%
datafr1=datafr1.drop(['atemp'],axis=1)
datafr1.head(2)
# Out:
#    instant    dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1   0        0        6           0
# 1        2  1/1/2011       1   0     1   1        0        6           0
#
#    weathersit  temp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.81        0.0       3          13   16
# 1           1  0.22  0.80        0.0       8          32   40

# %% [markdown]
# #### we eliminated 'atemp' because , it's just an assumption of 'temp' and not original value

# %%
sns.boxplot(data = datafr1,y='cnt',orient='v')
plt.show()

# %% [markdown]
# #### In the graph above, we can see that the count value is very large. In other words, we can see that there are many outliers. Let's look at the other variables to see how much of these exist. Let's divide the column for weather and the column for categorical.

# %%
fig,axes = plt.subplots(ncols=2 ,nrows=2)
fig.set_size_inches(15,10)
sns.boxplot(data=datafr1,x='season',y='cnt',ax=axes[0][0])
sns.boxplot(data=datafr1,x='holiday',y='cnt',ax=axes[0][1])
sns.boxplot(data=datafr1,x='workingday',y='cnt',ax=axes[1][0])
sns.boxplot(data=datafr1,x='weathersit',y='cnt',ax=axes[1][1])

# %% [markdown]
# #### The graph above shows a few things
#
# -------->Season shows that the spring is lower than the summer, autumn and winter counts.
#
# -------->It can be seen that there are quite a lot of outliers for Count.In Workingday, outlier is higher when you work than when you are not working.
#
# -------->Let's look at the relationship between the weather (temp,humidity, windspeed) and Count. Weather data can be viewed as Numeric data. Therefore, let's get the correlation coefficient and visualize.

# %%
corrs=datafr1[['temp','windspeed','hum','cnt']].corr()
sns.heatmap(corrs,annot=True,vmax=3)

# %%
fig,axes=plt.subplots(ncols=2,nrows=2)
fig.set_size_inches(15,10)
sns.regplot(data=datafr1,x='temp',y='cnt',ax=axes[0][0])
sns.regplot(data=datafr1,x='hum',y='cnt',ax=axes[1][0])
sns.regplot(data=datafr1,x='windspeed',y='cnt',ax=axes[1][1])
plt.show()

# %%
from time import time
datafr1['dteday'] = pd.to_datetime(datafr1['dteday'])    
datafr1['dteday'] = (datafr1['dteday'] - datafr1['dteday'].min()) / np.timedelta64(1,'D')

# %% [markdown]
# ##### Now , lets break our data into train and test

# %%
X_train,X_test,y_train,y_test = train_test_split(datafr1,datafr1['cnt'],
                                                    test_size=0.30, 
                                                    random_state=42)
print(X_train.shape)
print(X_test.shape)
# Out:
# (12165, 16)
# (5214, 16)

# %% [markdown]
# ### Building a decision tree regressor

# %%
from sklearn import metrics
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV, cross_val_score, cross_val_predict, train_test_split

dtm = DecisionTreeRegressor(max_depth=4,
                           min_samples_split=5,
                           max_leaf_nodes=10)
dtm.fit(X_train,y_train)
print("R-Squared on train dataset={}".format(dtm.score(X_test,y_test)))

dtm.fit(X_test,y_test)   
print("R-Squaredon test dataset={}".format(dtm.score(X_test,y_test)))
# Out:
# R-Squared on train dataset=0.9830603124114272
# R-Squaredon test dataset=0.9841492011460071

# %%
param_grid = {"criterion": ["mse", "mae"],"min_samples_split": [10, 20, 40],"max_depth": [2, 6, 8],"min_samples_leaf": [20, 40, 100],"max_leaf_nodes": [5, 20, 100]}
grid_cv_dtm = GridSearchCV(dtm, param_grid, cv=3,verbose=10)
grid_cv_dtm.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40, score=0.9325300182582534, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.1s remaining:    0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20
# [CV]  criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split
max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40, score=0.9353808927794564, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40, score=0.9325300182582534, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40, score=0.9363063679046612, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10, score=0.9959487158785603, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10, score=0.9957986218514804, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10, score=0.9961409898704923, total=   0.0s
# [CV] criterion=mse, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20
# [CV]  criterion=mse, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=

# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10, score=0.9997030726430028, total=   2.0s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10, score=0.9996186172305638, total=   2.1s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20, score=0.9997426822667189, total=   2.1s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20, score=0.9997030726430028, total=   2.3s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20, score=0.9996186172305638, total=   2.4s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40, score=0.9997426822667189, total=   2.7s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40, score=0.9997030726430028, total=   2.1s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40, score=0.9996186172305638, total=   2.1s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10, score=0.9992021710536872, total=   2.0s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10, score=0.9992428186914084, total=   2.0s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10, score=0.9989377622599822, total=   2.0s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20, score=0.9992021710536872, total=   2.0s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20, score=0.9992428186914084, total=   2.1s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20, score=0.9989377622599822, total=   2.0s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40, score=0.9992021710536872, total=   1.9s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40, score=0.9992428186914084, total=   2.0s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40, score=0.9989377622599822, total=   2.0s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10, score=0.9973639925630307, total=   1.9s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10, score=0.9968380345516745, total=   1.9s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10, score=0.9960183542106189, total=   1.9s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20, score=0.9973639925630307, total=   2.0s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20, score=0.9968380345516745, total=   1.9s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20, score=0.9960183542106189, total=   1.9s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40, score=0.9973639925630307, total=   1.9s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40, score=0.9968380345516745, total=   1.9s
# [CV] criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40
# [CV]  criterion=mae, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40, score=0.9960183542106189, total=   2.2s
# [Parallel(n_jobs=1)]: Done 486 out of 486 | elapsed:  7.9min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=DecisionTreeRegressor(criterion='mse', max_depth=4, max_features=None,
#            max_leaf_nodes=10, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=5, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'criterion': ['mse', 'mae'], 'min_samples_split': [10, 20, 40], 'max_depth': [2, 6, 8], 'min_samples_leaf': [20, 40, 100], 'max_leaf_nodes': [5, 20, 100]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=10)

# %%
print("R-Squared ={}".format(grid_cv_dtm.best_score_))
print("Best Hyperparameters::\n{}".format(grid_cv_dtm.best_params_))
# Out:
# R-Squared =0.9997237339523027
# Best Hyperparameters::
# {'criterion': 'mse', 'max_depth': 6, 'max_leaf_nodes': 100, 'min_samples_leaf': 20, 'min_samples_split': 10}

# %%
# converting above results into new data frame
dfx = pd.DataFrame(data=grid_cv_dtm.cv_results_)
dfx.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.018990      0.002122         0.001985        0.000015
# 1       0.017619      0.000940         0.001996        0.000814
# 2       0.022605      0.003085         0.001663        0.000470
# 3       0.017286      0.001694         0.001663        0.000470
# 4       0.016954      0.000814         0.001663        0.000471
#
#   param_criterion param_max_depth param_max_leaf_nodes param_min_samples_leaf  \
# 0             mse               2                    5                     20
# 1             mse               2                    5                     20
# 2             mse               2                    5                     20
# 3             mse               2                    5                     40
# 4             mse               2                    5                     40
#
#   param_min_samples_split                                             params  \
# 0                      10  {'criterion': 'mse', 'max_depth': 2, 'max_leaf...
# 1                      20  {'criterion': 'mse', 'max_depth': 2, 'max_leaf...
# 2                      40  {'criterion': 'mse', 'max_depth': 2, 'max_leaf...
# 3                      10  {'criterion': 'mse', 'max_depth': 2, 'max_leaf...
# 4                      20  {'criterion': 'mse', 'max_depth': 2, 'max_leaf...
#
#    ...  split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0  ...            0.93253           0.936306         0.934739        0.001607
# 1  ...            0.93253           0.936306         0.934739        0.001607
# 2  ...            0.93253           0.936306         0.934739        0.001607
# 3  ...            0.93253           0.936306         0.934739        0.001607
# 4  ...            0.93253           0.936306         0.934739        0.001607
#
#    rank_test_score  split0_train_score  split1_train_score  \
# 0              136            0.935062             0.93475
# 1              136            0.935062             0.93475
# 2              136            0.935062             0.93475
# 3              136            0.935062             0.93475
# 4              136            0.935062             0.93475
#
#    split2_train_score  mean_train_score  std_train_score
# 0            0.936806          0.935539         0.000905
# 1            0.936806          0.935539         0.000905
# 2            0.936806          0.935539         0.000905
# 3            0.936806          0.935539         0.000905
# 4            0.936806          0.935539         0.000905
#
# [5 rows x 21 columns]

# %%
fig,ax = plt.subplots()
sns.pointplot(data=dfx[['mean_test_score','param_max_leaf_nodes','param_max_depth']],
y='mean_test_score',x='param_max_depth',
             hue='param_max_leaf_nodes',ax=ax)
ax.set(title="Effect of Depth and Leaf Nodes on Model Performance")
# Out:
# [Text(0.5, 1.0, 'Effect of Depth and Leaf Nodes on Model Performance')]

# %%
# Checking the training model scores
r2_scores = cross_val_score(grid_cv_dtm.best_estimator_, X_train, y_train, cv=10,verbose=10)
mse_scores = cross_val_score(grid_cv_dtm.best_estimator_, X_train, y_train, cv=10,scoring='neg_mean_squared_error',verbose=10)

print("avg R-squared::{:.3f}".format(np.mean(r2_scores)))
print("MSE::{:.3f}".format(np.mean(mse_scores)))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [CV]  ................................................................
# [CV] ....................... , score=0.9997297140399145, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=0.9997656623969609, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=0.9998151263307712, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=0.9998060039750571, total=   0.0s
# [CV]  ................................................................
# [CV] ........................ , score=0.999620200310376, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=0.9997381646474882, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=0.9997289721332397, total=   0.0s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.2s remaining:    0.0s
# [CV] ....................... , score=0.9998036710821434, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=0.9995694787835033, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=0.9997701121700475, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=-9.360824123529682, total=   0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-7.6490488229051925, total=   0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV]  ................................................................
# [CV] ....................... , score=-5.716864886637386, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=-6.137401025708517, total=   0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-11.856386937280131, total=   0.0s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# [CV] ....................... , score=-9.518397488448835, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=-9.149385422403267, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=-7.018889560739784, total=   0.0s
# [CV]  ................................................................
# [CV] ...................... , score=-15.176839388038747, total=   0.0s
# [CV]  ................................................................
# [CV] ....................... , score=-7.368707145565111, total=   0.0s
# avg R-squared::1.000
# MSE::-8.895
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished

# %%
best_dtm_model = grid_cv_dtm.best_estimator_
y_pred = best_dtm_model.predict(X_test)
r2_score = best_dtm_model.score(X_test,y_test)
print("R-squared:{:.3f}".format(r2_score))
print("MSE: %.2f" % metrics.mean_squared_error(y_test, y_pred))
# Out:
# R-squared:1.000
# MSE: 7.93

# %% [markdown]
# ## Here, we got R^2 value as 1. which means, our DT regressor perfectly fits our data.

# %% [markdown]
# ### Let's fit a linear-regression model on top of our data

# %%
# from sklearn import linear_model
# from sklearn.metrics import mean_squared_error, r2_score
# # x=datafr1.iloc[:,:-1].values
# # y=datafr1.iloc[:,:1].values
# # X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
# reg_linear=linear_model.LinearRegression()
# reg_linear.fit(X_train,y_train)
# y_test_pred=reg_linear.predict(X_test)

# %% [markdown]
# #### Visualize our data

# %%
from sklearn import linear_model
X_train,X_test,y_train,y_test=train_test_split(datafr1,datafr1['cnt'],test_size=0.3,random_state=1)
# create linear regression object 
reg = linear_model.LinearRegression() 
  
# train the model using the training sets 
reg.fit(X_train, y_train) 
y_pred=reg.predict(X_test)
# regression coefficients 
print('Coefficients: \n', reg.coef_) 
  
# variance score: 1 means perfect prediction 
print('Variance score: {}'.format(reg.score(X_test, y_test))) 
  
# plot for residual error 
  
## setting plot style 
plt.style.use('fivethirtyeight') 
  
## plotting residual errors in training data 
plt.scatter(reg.predict(X_train), reg.predict(X_train) - y_train, 
            color = "red", s = 10, label = 'Train data') 
  
## plotting residual errors in test data 
plt.scatter(reg.predict(X_test), reg.predict(X_test) - y_test, 
            color = "blue", s = 10, label = 'Test data') 
  
## plotting line for zero residual error 
plt.hlines(y = 0, xmin = 0, xmax = 50, linewidth = 1) 
  
## plotting legend 
plt.legend(loc = 'upper right') 
  
## plot title 
plt.title("Residual errors") 
  
## function to show plot 
plt.show()
# Out:
# Coefficients:
#  [-2.88590007e-16  1.47690997e-14  1.25807706e-14 -8.63779016e-15
#  -7.01639714e-15  4.22499979e-15 -3.23945640e-14  8.70043905e-16
#  -2.08596974e-14 -5.51090523e-14 -1.08560269e-14  2.30465258e-13
#   4.88540852e-15  3.33333333e-01  3.33333333e-01  6.66666667e-01]
# Variance score: 1.0

# %% [markdown]
# ### Regression metrics

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import sklearn.metrics as sm
print('performance of linear regression')
print('--------------------------------------------------')
print('Mean absolute error = ',round(sm.mean_absolute_error(y_test,y_pred),2))
print('Mean squared error = ',round(sm.mean_squared_error(y_test,y_pred),2))
print('Median absolute error = ',round(sm.median_absolute_error(y_test,y_pred),2))
print('explained variance score = ',round(sm.explained_variance_score(y_test,y_pred),2))
print('R2 score = ',round(sm.r2_score(y_test,y_pred),2))
# Out:
# performance of linear regression
# --------------------------------------------------
# Mean absolute error =  0.0
# Mean squared error =  0.0
# Median absolute error =  0.0
# explained variance score =  1.0
# R2 score =  1.0
